# %%
import pandas as pd
collamnames=['Sepal Length','Sepal Width','Peatal length','Petal Width','Species']
df=pd.read_csv('iris.csv', names=collamnames, header=None )
df
# Out:
#      Sepal Length  Sepal Width  Peatal length  Petal Width         Species
# 0             5.1          3.5            1.4          0.2     Iris-setosa
# 1             4.9          3.0            1.4          0.2     Iris-setosa
# 2             4.7          3.2            1.3          0.2     Iris-setosa
# 3             4.6          3.1            1.5          0.2     Iris-setosa
# 4             5.0          3.6            1.4          0.2     Iris-setosa
# ..            ...          ...            ...          ...             ...
# 145           6.7          3.0            5.2          2.3  Iris-virginica
# 146           6.3          2.5            5.0          1.9  Iris-virginica
# 147           6.5          3.0            5.2          2.0  Iris-virginica
# 148           6.2          3.4            5.4          2.3  Iris-virginica
# 149           5.9          3.0            5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    Sepal Length  Sepal Width  Peatal length  Petal Width      Species
# 0           5.1          3.5            1.4          0.2  Iris-setosa
# 1           4.9          3.0            1.4          0.2  Iris-setosa
# 2           4.7          3.2            1.3          0.2  Iris-setosa
# 3           4.6          3.1            1.5          0.2  Iris-setosa
# 4           5.0          3.6            1.4          0.2  Iris-setosa

# %%
df.isna().sum()
# Out:
# Sepal Length     0
# Sepal Width      0
# Peatal length    0
# Petal Width      0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Sepal Length     float64
# Sepal Width      float64
# Peatal length    float64
# Petal Width      float64
# Species           object
# dtype: object

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.max()
# Out:
# Sepal Length                7.9
# Sepal Width                 4.4
# Peatal length               6.9
# Petal Width                 2.5
# Species          Iris-virginica
# dtype: object

# %%
df.min()
# Out:
# Sepal Length             4.3
# Sepal Width              2.0
# Peatal length            1.0
# Petal Width              0.1
# Species          Iris-setosa
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
label_encoder=LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])
df.head()
# Out:
#    Sepal Length  Sepal Width  Peatal length  Petal Width  Species
# 0           5.1          3.5            1.4          0.2        0
# 1           4.9          3.0            1.4          0.2        0
# 2           4.7          3.2            1.3          0.2        0
# 3           4.6          3.1            1.5          0.2        0
# 4           5.0          3.6            1.4          0.2        0

# %%
df['Species'].value_counts()
# Out:
# Species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
x=df.drop('Species', axis=1)
x
# Out:
#      Sepal Length  Sepal Width  Peatal length  Petal Width
# 0             5.1          3.5            1.4          0.2
# 1             4.9          3.0            1.4          0.2
# 2             4.7          3.2            1.3          0.2
# 3             4.6          3.1            1.5          0.2
# 4             5.0          3.6            1.4          0.2
# ..            ...          ...            ...          ...
# 145           6.7          3.0            5.2          2.3
# 146           6.3          2.5            5.0          1.9
# 147           6.5          3.0            5.2          2.0
# 148           6.2          3.4            5.4          2.3
# 149           5.9          3.0            5.1          1.8
#
# [150 rows x 4 columns]

# %%
y=df['Species']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int32

# %%
#using sklearn split our data set in two data sets
X_train,X_test,Y_train,Y_test=train_test_split(x,y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      Sepal Length  Sepal Width  Peatal length  Petal Width
# 22            4.6          3.6            1.0          0.2
# 15            5.7          4.4            1.5          0.4
# 65            6.7          3.1            4.4          1.4
# 11            4.8          3.4            1.6          0.2
# 42            4.4          3.2            1.3          0.2
# ..            ...          ...            ...          ...
# 71            6.1          2.8            4.0          1.3
# 106           4.9          2.5            4.5          1.7
# 14            5.8          4.0            1.2          0.2
# 92            5.8          2.6            4.0          1.2
# 102           7.1          3.0            5.9          2.1
#
# [120 rows x 4 columns]

# %%
X_test
X_test.shape
# Out:
# (30, 4)

# %%
dt_classifier=DecisionTreeClassifier(random_state=42)
dt_classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
Y_predict=dt_classifier.predict(X_train)
Y_predict
# Out:
# array([0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0, 0, 1, 2, 2, 1, 2, 1, 2,
#        1, 0, 2, 1, 0, 0, 0, 1, 2, 0, 0, 0, 1, 0, 1, 2, 0, 1, 2, 0, 2, 2,
#        1, 1, 2, 1, 0, 1, 2, 0, 0, 1, 1, 0, 2, 0, 0, 1, 1, 2, 1, 2, 2, 1,
#        0, 0, 2, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1, 1, 2, 1, 2, 0, 2, 1, 2,
#        1, 1, 1, 0, 1, 1, 0, 1, 2, 2, 0, 1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2,
#        1, 1, 2, 2, 0, 1, 2, 0, 1, 2])

# %%
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
Y_predict.shape
# Out:
# (120,)

# %%
accuracy=accuracy_score(Y_predict,Y_train)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:1.00

# %%
test_predict=dt_classifier.predict(X_test)
test_predict
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
accuracy=accuracy_score(test_predict,Y_test)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:1.00

# %%
#Task 2
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix
train=pd.read_csv('Train.csv')
label_encoder=LabelEncoder()
train['Class']=label_encoder.fit_transform(train['Class'])
train
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  ...  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     54180    951.753       388.728347       178.948203  ...      0.000922      0.456517      0.991689      4
# 1     42023    746.715       272.962686       196.334047  ...      0.002066      0.718109      0.998386      3
# 2     38600    716.517       254.129288       193.991641  ...      0.002352      0.761006      0.996919      5
# 3     62298    992.583       327.685094       242.658033  ...      0.001771      0.738705      0.997546      0
# 4     74456   1085.466       447.665972       212.382328  ...      0.000830      0.473044      0.997097      4
# ...     ...        ...              ...              ...  ...           ...           ...           ...    ...
# 9523  55381    914.969       363.142352       194.498350  ...      0.001156      0.534709      0.998339      4
# ...

# %%
test=pd.read_csv('Test.csv')
test['Class']=label_encoder.fit_transform(test['Class'])
test
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  ...  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     29380    624.110       212.826130       175.931143  ...      0.003048      0.825871      0.999066      5
# 1     30008    645.884       210.557999       182.516516  ...      0.003215      0.861794      0.994199      5
# 2     30279    634.927       212.560556       181.510182  ...      0.003153      0.853270      0.999236      5
# 3     31107    640.594       214.648549       184.969253  ...      0.003145      0.859632      0.997564      5
# 4     31203    639.782       215.067737       184.874876  ...      0.003137      0.858926      0.999202      5
# ...     ...        ...              ...              ...  ...           ...           ...           ...    ...
# 4078  41979    757.238       272.579920       196.580706  ...      0.002073      0.719374      0.997487      3
# ...

# %%
train.shape
# Out:
# (9528, 17)

# %%
test.shape
# Out:
# (4083, 17)

# %%
train.describe()
# Out:
#                 Area    Perimeter  MajorAxisLength  ...  ShapeFactor3  ShapeFactor4        Class
# count    9528.000000  9528.000000      9528.000000  ...   9528.000000   9528.000000  9528.000000
# mean    53255.524664   856.676016       320.572294  ...      0.644190      0.995117     3.540722
# std     29609.257209   215.627112        86.225872  ...      0.099502      0.004259     1.834847
# min     20464.000000   524.736000       183.965251  ...      0.410339      0.947687     0.000000
# 25%     36453.750000   704.791500       253.499188  ...      0.581809      0.993739     2.000000
# 50%     44754.500000   796.506000       297.211791  ...      0.642568      0.996396     3.000000
# 75%     61444.750000   977.826000       376.865074  ...      0.696476      0.997909     5.000000
# max    254616.000000  1985.370000       738.860153  ...      0.963560      0.999733     6.000000
#
# [8 rows x 17 columns]

# %%
test.describe()
# Out:
#                 Area    Perimeter  MajorAxisLength  ...  ShapeFactor3  ShapeFactor4        Class
# count    4083.000000  4083.000000      4083.000000  ...   4083.000000   4083.000000  4083.000000
# mean    52564.673524   852.033817       319.137432  ...      0.642191      0.994937     3.513838
# std     28645.358590   211.126243        84.442374  ...      0.097803      0.004605     1.814389
# min     20420.000000   524.932000       183.601165  ...      0.424623      0.955032     0.000000
# 25%     36087.000000   701.621500       252.660111  ...      0.580506      0.993614     2.000000
# 50%     44453.000000   791.480000       296.398632  ...      0.640830      0.996358     3.000000
# 75%     61035.000000   974.456000       375.418250  ...      0.695207      0.997814     5.000000
# max    237270.000000  1921.685000       738.144502  ...      0.974767      0.999612     6.000000
#
# [8 rows x 17 columns]

# %%
train.isna().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
test.isna().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
train['Class'].value_counts()
# Out:
# Class
# 3    2427
# 6    1850
# 5    1468
# 4    1341
# 2    1137
# 0     928
# 1     377
# Name: count, dtype: int64

# %%
test['Class'].value_counts()
# Out:
# Class
# 3    1119
# 6     786
# 4     587
# 5     559
# 2     493
# 0     394
# 1     145
# Name: count, dtype: int64

# %%
X_train=train.drop('Class' , axis=1)
Y_train=train['Class']
X_train
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  ...  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0     54180    951.753       388.728347       178.948203  ...      0.007175      0.000922      0.456517      0.991689
# 1     42023    746.715       272.962686       196.334047  ...      0.006496      0.002066      0.718109      0.998386
# 2     38600    716.517       254.129288       193.991641  ...      0.006584      0.002352      0.761006      0.996919
# 3     62298    992.583       327.685094       242.658033  ...      0.005260      0.001771      0.738705      0.997546
# 4     74456   1085.466       447.665972       212.382328  ...      0.006012      0.000830      0.473044      0.997097
# ...     ...        ...              ...              ...  ...           ...           ...           ...           ...
# 9523  55381    914.969       363.142352       194.498350  ...      0.006557      0.001156      0.534709      0.998339
# ...

# %%
Y_train
# Out:
# 0       4
# 1       3
# 2       5
# 3       0
# 4       4
#        ..
# 9523    4
# 9524    6
# 9525    3
# 9526    4
# 9527    6
# Name: Class, Length: 9528, dtype: int32

# %%
dt_classifier=DecisionTreeClassifier(random_state=34)
dt_classifier.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=34)

# %%
train_predict=dt_classifier.predict(X_train)
train_predict
# Out:
# array([4, 3, 5, ..., 3, 4, 6])

# %%
accuracy=accuracy_score(train_predict,Y_train)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:1.00

# %%
x_test=test.drop('Class' , axis=1)
y_test=test['Class']
x_test
# Out:
#        Area  Perimeter  MajorAxisLength  MinorAxisLength  ...  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4
# 0     29380    624.110       212.826130       175.931143  ...      0.007244      0.003048      0.825871      0.999066
# 1     30008    645.884       210.557999       182.516516  ...      0.007017      0.003215      0.861794      0.994199
# 2     30279    634.927       212.560556       181.510182  ...      0.007020      0.003153      0.853270      0.999236
# 3     31107    640.594       214.648549       184.969253  ...      0.006900      0.003145      0.859632      0.997564
# 4     31203    639.782       215.067737       184.874876  ...      0.006893      0.003137      0.858926      0.999202
# ...     ...        ...              ...              ...  ...           ...           ...           ...           ...
# 4078  41979    757.238       272.579920       196.580706  ...      0.006493      0.002073      0.719374      0.997487
# ...

# %%
y_test
# Out:
# 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 4078    3
# 4079    3
# 4080    3
# 4081    3
# 4082    3
# Name: Class, Length: 4083, dtype: int32

# %%
test_predict=dt_classifier.predict(x_test)
test_predict
# Out:
# array([5, 5, 5, ..., 6, 5, 3])

# %%
accuracy=accuracy_score(test_predict,y_test)
print(f'accuracy:{accuracy:.2f}')
# Out:
# accuracy:0.89
